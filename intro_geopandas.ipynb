# %% [markdown]
# <a href="https://colab.research.google.com/github/Guz5/intro-geopandas/blob/main/intro_geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd

# %%
gdf_localidades = gpd.read_file("localidades.json")

# %%
gdf_localidades.crs
# Out:
# <Geographic 2D CRS: EPSG:4686>
# Name: MAGNA-SIRGAS
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Colombia - onshore and offshore. Includes San Andres y Providencia, Malpelo Islands, Roncador Bank, Serrana Bank and Serranilla Bank.
# - bounds: (-84.77, -4.23, -66.87, 15.51)
# Datum: Marco Geocentrico Nacional de Referencia
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
gdf_localidades.to_crs(epsg=9377, inplace=True)
gdf_localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
gdf_localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
gdf_localidades["centroide"]=gdf_localidades.centroid
gdf_localidades
# Out:
#     OBJECTID           LocNombre                            LocAAdmini  \
# 0         81      ANTONIO NARIÑO                   Acuerdo 117 de 2003
# 1         82          TUNJUELITO                   Acuerdo 117 de 2003
# 2         83  RAFAEL URIBE URIBE                   Acuerdo 117 de 2003
# 3         84          CANDELARIA                   Acuerdo 117 de 2003
# 4         85      BARRIOS UNIDOS                     Acuerdo 8 de 1977
# 5         86         TEUSAQUILLO                     Acuerdo 8 de 1977
# 6         87       PUENTE ARANDA                     Acuerdo 8 de 1977
# 7         88        LOS MARTIRES                     Acuerdo 8 de 1977
# 8         89             SUMAPAZ                     Acuerdo 9 de 1986
# 9         90             USAQUEN  Acuerdo 8 de 1977 y Res 1751 de 2016
# 10        91           CHAPINERO  Acuerdo 8 de 1977 y Res 1751 de 2016
# 11        92            SANTA FE                   Acuerdo 117 de 2003
# ...

# %%
from shapely.geometry import Point
import geopandas as gpd

# %%
#point(longitud, latitud)
universidad = Point(-74.06659808643116, 4.628283807240232)
universidad
# Out:
# <POINT (-74.067 4.628)>

# %%
universidad= gpd.GeoSeries(universidad, crs=4326)
universidad
# Out:
# 0    POINT (-74.06660 4.62828)
# dtype: geometry

# %%
universidades=universidad.to_crs(epsg=9377)
universidades
# Out:
# 0    POINT (4881739.326 2069509.229)
# dtype: geometry

# %%
gdf_localidades["distancia"]=[float(universidad.distance(centroide)) /1000 for centroide in gdf_localidades.centroide]
gdf_localidades["distancia"]
# Out:
# <ipython-input-13-7b714e47ad2a>:1: UserWarning: Geometry is in a geographic CRS. Results from 'distance' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_localidades["distancia"]=[float(universidad.distance(centroide)) /1000 for centroide in gdf_localidades.centroide]
# <ipython-input-13-7b714e47ad2a>:1: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   gdf_localidades["distancia"]=[float(universidad.distance(centroide)) /1000 for centroide in gdf_localidades.centroide]
# 0     5296.945422
# 1     5292.960225
# 2     5294.907957
# 3     5300.424587
# 4     5303.432845
# 5     5300.955803
# 6     5297.242750
# 7     5299.260601
# 8     5257.558406
# 9     5311.231330
# 10    5306.099727
# 11    5303.970262
# 12    5298.970585
# 13    5284.303400
# 14    5286.320537
# 15    5289.035782
# 16    5293.662654
# ...

# %%
gdf_localidades.plot()
# Out:
# <Axes: >

# %%
# agregar capas
mape=gdf_localidades.plot(figsize=(10,10))
gdf_localidades["centroide"].plot(ax=mape, color="white")
# Out:
# <Axes: >

# %% [markdown]
# # Importar contextyle

# %%
mapa_2= gdf_localidades.plot(
  column= 'LocNombre',
  figsize=(15,15),
  edgecolor="grey",
  cmap= 'tab20',
  legend=True,
  legend_kwds= {
      'loc': "upper left"
  }
)

# %% [markdown]
# # TAREA
#
# ## *Crear mapa soropletico con los barrios de la localidad donde vivo*
